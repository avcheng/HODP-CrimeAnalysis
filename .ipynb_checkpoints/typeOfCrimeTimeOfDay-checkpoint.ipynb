# %%
import numpy as np
import pandas as pd
import csv
import datetime as dtt
import matplotlib.pyplot as plt
from datetime import datetime
from collections import Counter 

import matplotlib.font_manager
matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
# Out:
# ['/System/Library/Fonts/SFNSDisplayCondensed-Regular.otf',
#  '/Library/Fonts/Trebuchet MS Italic.ttf',
#  '/Library/Fonts/Hoefler Text Ornaments.ttf',
#  '/System/Library/Fonts/SFCompactRounded-Heavy.otf',
#  '/Library/Fonts/Times New Roman.ttf',
#  '/System/Library/Fonts/SFCompactDisplay-Medium.otf',
#  '/Library/Fonts/Verdana Bold.ttf',
#  '/System/Library/Fonts/SFCompactRounded-Medium.otf',
#  '/Library/Fonts/Arial Unicode.ttf',
#  '/Library/Fonts/STIXSizThreeSymReg.otf',
#  '/Library/Fonts/GothamBookItalic.ttf',
#  '/Library/Fonts/DIN Condensed Bold.ttf',
#  '/System/Library/Fonts/SFNSDisplay-ThinG1.otf',
#  '/System/Library/Fonts/SFNSDisplay-BoldItalic.otf',
#  '/Library/Fonts/Herculanum.ttf',
#  '/Library/Fonts/Arial.ttf',
#  '/System/Library/Fonts/SFCompactDisplay-Semibold.otf',
#  '/Library/Fonts/AppleGothic.ttf',
#  '/System/Library/Fonts/SFNSTextCondensed-Bold.otf',
#  '/Library/Fonts/Arial Narrow.ttf',
#  '/System/Library/Fonts/SFNSDisplayCondensed-Bold.otf',
# ...

# %%
file = pd.read_csv("crime_data_log.csv")

df = pd.DataFrame()
df['time'] = file['Time Reported']
df['type'] = file['Type']

# %%
df['time'] = pd.to_datetime(df['time'], format='%I:%M %p', errors='coerce').dt.time

# %%
hours = {}
crime_type_dict = {}

for idx, i in enumerate(df['time']):
    for hour in range(23):
        if i > dtt.time(hour,0,0) and i < dtt.time(hour + 1,0,0):
            if hour in hours:
                crime_type = df.loc[idx,'type']
                if type(crime_type) is str:
                    if crime_type in crime_type_dict:
                        crime_type_dict[crime_type] += 1
                    else:
                        crime_type_dict[crime_type] = 1
                hours[hour] += 1
            else:
                crime_type = df.loc[idx,'type']
                if type(crime_type) is str:
                    if crime_type in crime_type_dict:
                        crime_type_dict[crime_type] += 1
                    else:
                        crime_type_dict[crime_type] = 1
                hours[hour] = 1

# %%
plt.figure(figsize=(20,10))
plt.xlabel('Hour', fontsize = 9)
plt.ylabel('Number of Crimes', fontsize = 9)
plt.title('Number of Crimes Over Hour in a Day\nHavard Yard Area', fontsize = 11)
plt.bar(list(hours.keys()), hours.values(), color="#D2232A")
plt.show()

# %%
k = Counter(crime_type_dict) 
  
high = k.most_common(20)  

high.sort(key=lambda x: x[1], reverse=True) 
crimetype = zip(*high)[0]
amount = zip(*high)[1]
x_pos = np.arange(len(crimetype)) 

plt.figure(figsize=(20,10))
plt.xlabel('Type of Crime', fontsize = 15)
plt.title('Most Common Crimes (Top 20 Crimes)', fontsize = 25)
plt.bar(x_pos, amount, align='center', color="#D2232A")
plt.xticks(x_pos, crimetype, rotation=-60, fontsize=14, ha='left')
plt.ylabel('Frequency of Crime', fontsize = 15)

plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xlabel('Type of Crime', fontsize = 9)
plt.xticks(rotation='vertical', fontsize = 9) 
plt.ylabel('Frequency of Crime', fontsize = 9)
plt.title('Most Common Crime', fontsize = 11)
plt.bar(list(crime_type_dict.keys()), crime_type_dict.values(), color='#D2232A')
plt.show()
